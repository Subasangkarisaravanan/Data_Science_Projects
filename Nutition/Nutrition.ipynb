# %%
import requests
url_obesity_adults = 'https://ghoapi.azureedge.net/api/NCD_BMI_30C'
url_obesity_children = 'https://ghoapi.azureedge.net/api/NCD_BMI_PLUS2C'
url_underweight_adults = 'https://ghoapi.azureedge.net/api/NCD_BMI_18C'
url_underweight_children = 'https://ghoapi.azureedge.net/api/NCD_BMI_MINUS2C'
response_obesity_adults = requests.get(url_obesity_adults)
response_obesity_children = requests.get(url_obesity_children)
response_underweight_adults = requests.get(url_underweight_adults)
response_underweight_children = requests.get(url_underweight_children)
data_obesity_adults = response_obesity_adults.json()
data_obesity_children = response_obesity_children.json()
data_underweight_adults = response_underweight_adults.json()
data_underweight_children = response_underweight_children.json()
data_obesity_adults
data_obesity_children
data_underweight_adults
data_underweight_children
# Out:
# {'@odata.context': 'https://ghoapi.azureedge.net/api/$metadata#NCD_BMI_MINUS2C',
#  'value': [{'Id': 7573110,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'TUV',
#    'ParentLocationCode': 'WPR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2005,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '0.8 [0.1-2.1]',
#    'NumericValue': 0.75219362,
#    'Low': 0.13741521,
#    'High': 2.1450212,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2005',
#    'TimeDimensionBegin': '2005-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2005-12-31T00:00:00+01:00'},
#   {'Id': 7573189,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'DNK',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2001,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '1.6 [1.2-2.0]',
#    'NumericValue': 1.5783301,
#    'Low': 1.1792589,
#    'High': 2.0376995,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2001',
#    'TimeDimensionBegin': '2001-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2001-12-31T00:00:00+01:00'},
#   {'Id': 7573624,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'NGA',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 1999,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '21.5 [14.6-28.9]',
#    'NumericValue': 21.477319,
#    'Low': 14.60585,
#    'High': 28.87215,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1999',
#    'TimeDimensionBegin': '1999-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1999-12-31T00:00:00+01:00'},
#   {'Id': 7573803,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BRB',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2002,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '5.1 [1.5-11.8]',
#    'NumericValue': 5.0708085,
#    'Low': 1.4641194,
#    'High': 11.820976,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2002',
#    'TimeDimensionBegin': '2002-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2002-12-31T00:00:00+01:00'},
#   {'Id': 7574229,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BFA',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2015,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '8.5 [4.7-13.5]',
#    'NumericValue': 8.4906258,
#    'Low': 4.676703,
#    'High': 13.481808,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2015',
#    'TimeDimensionBegin': '2015-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2015-12-31T00:00:00+01:00'},
#   {'Id': 7574654,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'HTI',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2019,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '3.8 [1.9-6.8]',
#    'NumericValue': 3.8472809,
#    'Low': 1.899242,
#    'High': 6.7705847,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2019',
#    'TimeDimensionBegin': '2019-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2019-12-31T00:00:00+01:00'},
#   {'Id': 7574742,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BRB',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2007,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '4.3 [2.8-6.3]',
#    'NumericValue': 4.3388624,
#    'Low': 2.8122624,
#    'High': 6.2576272,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2007',
#    'TimeDimensionBegin': '2007-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2007-12-31T00:00:00+01:00'},
#   {'Id': 7574762,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARM',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 1997,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '3.4 [1.3-6.9]',
#    'NumericValue': 3.4054998,
#    'Low': 1.3241483,
#    'High': 6.9211945,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1997',
#    'TimeDimensionBegin': '1997-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1997-12-31T00:00:00+01:00'},
#   {'Id': 7574773,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ETH',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2001,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '23.3 [19.2-27.3]',
#    'NumericValue': 23.336248,
#    'Low': 19.210002,
#    'High': 27.325132,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2001',
#    'TimeDimensionBegin': '2001-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2001-12-31T00:00:00+01:00'},
#   {'Id': 7574912,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'PRY',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2016,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '2.7 [0.8-6.4]',
#    'NumericValue': 2.704717,
#    'Low': 0.81560602,
#    'High': 6.3958749,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2016',
#    'TimeDimensionBegin': '2016-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2016-12-31T00:00:00+01:00'},
#   {'Id': 7574949,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ARE',
#    'ParentLocationCode': 'EMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2019,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '4.7 [2.9-7.2]',
#    'NumericValue': 4.7380351,
#    'Low': 2.8527062,
#    'High': 7.2280079,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2019',
#    'TimeDimensionBegin': '2019-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2019-12-31T00:00:00+01:00'},
#   {'Id': 7574980,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'TTO',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2004,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '10.6 [9.0-12.2]',
#    'NumericValue': 10.572087,
#    'Low': 8.9740798,
#    'High': 12.249024,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2004',
#    'TimeDimensionBegin': '2004-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2004-12-31T00:00:00+01:00'},
#   {'Id': 7574993,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BGR',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 1993,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '2.9 [2.3-3.5]',
#    'NumericValue': 2.8714221,
#    'Low': 2.2696242,
#    'High': 3.5473149,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1993',
#    'TimeDimensionBegin': '1993-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1993-12-31T00:00:00+01:00'},
#   {'Id': 7575146,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GAB',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 1995,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '7.2 [2.9-13.7]',
#    'NumericValue': 7.2116368,
#    'Low': 2.9244047,
#    'High': 13.72118,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1995',
#    'TimeDimensionBegin': '1995-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1995-12-31T00:00:00+01:00'},
#   {'Id': 7575182,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'LUX',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 1996,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '1.5 [0.3-4.2]',
#    'NumericValue': 1.526517,
#    'Low': 0.29600144,
#    'High': 4.230867,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1996',
#    'TimeDimensionBegin': '1996-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1996-12-31T00:00:00+01:00'},
#   {'Id': 7575262,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'CAF',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2008,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '13.8 [5.0-25.8]',
#    'NumericValue': 13.823871,
#    'Low': 4.989155,
#    'High': 25.834706,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2008',
#    'TimeDimensionBegin': '2008-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2008-12-31T00:00:00+01:00'},
#   {'Id': 7575416,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'NER',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2007,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '13.1 [7.4-20.1]',
#    'NumericValue': 13.089761,
#    'Low': 7.368087,
#    'High': 20.058411,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2007',
#    'TimeDimensionBegin': '2007-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2007-12-31T00:00:00+01:00'},
#   {'Id': 7575472,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'TCD',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2000,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '10.1 [4.5-18.0]',
#    'NumericValue': 10.093249,
#    'Low': 4.4574812,
#    'High': 17.985721,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2000',
#    'TimeDimensionBegin': '2000-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2000-12-31T00:00:00+01:00'},
#   {'Id': 7575558,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ETH',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 1996,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '10.1 [6.3-14.9]',
#    'NumericValue': 10.142244,
#    'Low': 6.2506288,
#    'High': 14.857495,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1996',
#    'TimeDimensionBegin': '1996-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1996-12-31T00:00:00+01:00'},
#   {'Id': 7575697,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BIH',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2007,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '3.4 [1.4-6.8]',
#    'NumericValue': 3.4343675,
#    'Low': 1.3574398,
#    'High': 6.8061069,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2007',
#    'TimeDimensionBegin': '2007-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2007-12-31T00:00:00+01:00'},
#   {'Id': 7575788,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ZMB',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2012,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '5.9 [3.5-8.9]',
#    'NumericValue': 5.8998663,
#    'Low': 3.4878738,
#    'High': 8.9459762,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2012',
#    'TimeDimensionBegin': '2012-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2012-12-31T00:00:00+01:00'},
#   {'Id': 7575985,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AUS',
#    'ParentLocationCode': 'WPR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2014,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '0.8 [0.6-1.1]',
#    'NumericValue': 0.84807416,
#    'Low': 0.64050276,
#    'High': 1.0902847,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2014',
#    'TimeDimensionBegin': '2014-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2014-12-31T00:00:00+01:00'},
#   {'Id': 7576028,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'TGO',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 1991,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '16.7 [9.4-25.8]',
#    'NumericValue': 16.68791,
#    'Low': 9.4198689,
#    'High': 25.838339,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1991',
#    'TimeDimensionBegin': '1991-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1991-12-31T00:00:00+01:00'},
#   {'Id': 7576068,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ISL',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 1997,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '1.7 [0.3-4.6]',
#    'NumericValue': 1.6877038,
#    'Low': 0.34671698,
#    'High': 4.5705486,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1997',
#    'TimeDimensionBegin': '1997-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1997-12-31T00:00:00+01:00'},
#   {'Id': 7576320,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'DNK',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 1997,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '2.0 [1.6-2.4]',
#    'NumericValue': 1.9628592,
#    'Low': 1.5521255,
#    'High': 2.4334803,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1997',
#    'TimeDimensionBegin': '1997-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1997-12-31T00:00:00+01:00'},
#   {'Id': 7576328,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GMB',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2005,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '9.2 [4.1-16.4]',
#    'NumericValue': 9.1652706,
#    'Low': 4.1361257,
#    'High': 16.445042,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2005',
#    'TimeDimensionBegin': '2005-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2005-12-31T00:00:00+01:00'},
#   {'Id': 7576451,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'CHE',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 1998,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '1.2 [0.8-1.8]',
#    'NumericValue': 1.1997371,
#    'Low': 0.7710556,
#    'High': 1.7570317,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1998',
#    'TimeDimensionBegin': '1998-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1998-12-31T00:00:00+01:00'},
#   {'Id': 7576631,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'PRT',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2014,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '1.3 [1.1-1.6]',
#    'NumericValue': 1.339654,
#    'Low': 1.0940265,
#    'High': 1.6223667,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2014',
#    'TimeDimensionBegin': '2014-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2014-12-31T00:00:00+01:00'},
#   {'Id': 7576791,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'COG',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2001,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '8.8 [4.5-14.4]',
#    'NumericValue': 8.811444,
#    'Low': 4.5361079,
#    'High': 14.393243,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2001',
#    'TimeDimensionBegin': '2001-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2001-12-31T00:00:00+01:00'},
#   {'Id': 7576999,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'NPL',
#    'ParentLocationCode': 'SEAR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'South-East Asia',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2001,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '16.8 [9.9-24.6]',
#    'NumericValue': 16.78025,
#    'Low': 9.8902635,
#    'High': 24.615559,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2001',
#    'TimeDimensionBegin': '2001-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2001-12-31T00:00:00+01:00'},
#   {'Id': 7577323,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BRN',
#    'ParentLocationCode': 'WPR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2019,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '3.1 [1.8-4.8]',
#    'NumericValue': 3.0850086,
#    'Low': 1.8231042,
#    'High': 4.7664214,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2019',
#    'TimeDimensionBegin': '2019-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2019-12-31T00:00:00+01:00'},
#   {'Id': 7577381,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'CUB',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2006,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '6.1 [4.0-8.7]',
#    'NumericValue': 6.0551006,
#    'Low': 3.9762452,
#    'High': 8.6561911,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2006',
#    'TimeDimensionBegin': '2006-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2006-12-31T00:00:00+01:00'},
#   {'Id': 7577496,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ROU',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2005,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '4.9 [4.1-5.8]',
#    'NumericValue': 4.9265075,
#    'Low': 4.1003361,
#    'High': 5.8144938,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2005',
#    'TimeDimensionBegin': '2005-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2005-12-31T00:00:00+01:00'},
#   {'Id': 7577679,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GAB',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2017,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '4.6 [1.9-9.4]',
#    'NumericValue': 4.6462346,
#    'Low': 1.8689148,
#    'High': 9.3552433,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2017',
#    'TimeDimensionBegin': '2017-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2017-12-31T00:00:00+01:00'},
#   {'Id': 7577710,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FIN',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2001,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '2.3 [1.2-3.9]',
#    'NumericValue': 2.2858243,
#    'Low': 1.1734801,
#    'High': 3.8644429,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2001',
#    'TimeDimensionBegin': '2001-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2001-12-31T00:00:00+01:00'},
#   {'Id': 7577775,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'REGION',
#    'SpatialDim': 'WPR',
#    'ParentLocationCode': None,
#    'TimeDimType': 'YEAR',
#    'ParentLocation': None,
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2011,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '6.3 [6.0-6.7]',
#    'NumericValue': 6.340409,
#    'Low': 5.998283,
#    'High': 6.699149,
#    'Comments': None,
#    'Date': '2024-05-23T13:28:38.2+02:00',
#    'TimeDimensionValue': '2011',
#    'TimeDimensionBegin': '2011-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2011-12-31T00:00:00+01:00'},
#   {'Id': 7577881,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GNQ',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 1993,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '12.1 [2.9-26.5]',
#    'NumericValue': 12.133338,
#    'Low': 2.8740373,
#    'High': 26.458603,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1993',
#    'TimeDimensionBegin': '1993-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1993-12-31T00:00:00+01:00'},
#   {'Id': 7578219,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'COK',
#    'ParentLocationCode': 'WPR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2004,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '0.6 [0.2-1.3]',
#    'NumericValue': 0.57104235,
#    'Low': 0.17500164,
#    'High': 1.3048177,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2004',
#    'TimeDimensionBegin': '2004-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2004-12-31T00:00:00+01:00'},
#   {'Id': 7578838,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'UZB',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2012,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '3.2 [1.9-4.8]',
#    'NumericValue': 3.1837553,
#    'Low': 1.933823,
#    'High': 4.7918081,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2012',
#    'TimeDimensionBegin': '2012-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2012-12-31T00:00:00+01:00'},
#   {'Id': 7578929,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AUS',
#    'ParentLocationCode': 'WPR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 1991,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '0.7 [0.5-1.1]',
#    'NumericValue': 0.74074068,
#    'Low': 0.45510251,
#    'High': 1.1074053,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1991',
#    'TimeDimensionBegin': '1991-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1991-12-31T00:00:00+01:00'},
#   {'Id': 7580432,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'EST',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 1992,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '2.4 [1.3-3.9]',
#    'NumericValue': 2.3830855,
#    'Low': 1.3050366,
#    'High': 3.9280806,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1992',
#    'TimeDimensionBegin': '1992-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1992-12-31T00:00:00+01:00'},
#   {'Id': 7580464,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AGO',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 1992,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '10.3 [2.6-22.5]',
#    'NumericValue': 10.288336,
#    'Low': 2.6486419,
#    'High': 22.530273,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1992',
#    'TimeDimensionBegin': '1992-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1992-12-31T00:00:00+01:00'},
#   {'Id': 7580676,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'SGP',
#    'ParentLocationCode': 'WPR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2020,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '3.6 [1.1-7.9]',
#    'NumericValue': 3.6027558,
#    'Low': 1.0965864,
#    'High': 7.9445668,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2020',
#    'TimeDimensionBegin': '2020-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2020-12-31T00:00:00+01:00'},
#   {'Id': 7580984,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GTM',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2010,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '0.9 [0.5-1.3]',
#    'NumericValue': 0.87353131,
#    'Low': 0.54877959,
#    'High': 1.2914208,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2010',
#    'TimeDimensionBegin': '2010-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2010-12-31T00:00:00+01:00'},
#   {'Id': 7581250,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'IRQ',
#    'ParentLocationCode': 'EMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2006,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '4.7 [1.2-11.1]',
#    'NumericValue': 4.7218915,
#    'Low': 1.1772873,
#    'High': 11.104521,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2006',
#    'TimeDimensionBegin': '2006-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2006-12-31T00:00:00+01:00'},
#   {'Id': 7581264,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GRD',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2004,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '4.2 [1.6-8.5]',
#    'NumericValue': 4.2442862,
#    'Low': 1.6468745,
#    'High': 8.459089,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2004',
#    'TimeDimensionBegin': '2004-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2004-12-31T00:00:00+01:00'},
#   {'Id': 7581446,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'DJI',
#    'ParentLocationCode': 'EMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2017,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '7.4 [3.2-13.4]',
#    'NumericValue': 7.3879756,
#    'Low': 3.158943,
#    'High': 13.44679,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2017',
#    'TimeDimensionBegin': '2017-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2017-12-31T00:00:00+01:00'},
#   {'Id': 7581478,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BHS',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2019,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '3.9 [1.8-7.0]',
#    'NumericValue': 3.9254766,
#    'Low': 1.7750232,
#    'High': 7.0124023,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2019',
#    'TimeDimensionBegin': '2019-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2019-12-31T00:00:00+01:00'},
#   {'Id': 7582208,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'MOZ',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2021,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '3.4 [1.2-7.2]',
#    'NumericValue': 3.4281686,
#    'Low': 1.204517,
#    'High': 7.1702026,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2021',
#    'TimeDimensionBegin': '2021-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2021-12-31T00:00:00+01:00'},
#   {'Id': 7582214,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'WORLDBANKINCOMEGROUP',
#    'SpatialDim': 'WB_UMI',
#    'ParentLocationCode': None,
#    'TimeDimType': 'YEAR',
#    'ParentLocation': None,
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 1998,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '6.9 [6.4-7.5]',
#    'NumericValue': 6.904991,
#    'Low': 6.3503526,
#    'High': 7.4851692,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1998',
#    'TimeDimensionBegin': '1998-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1998-12-31T00:00:00+01:00'},
#   {'Id': 7582788,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'HND',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 1990,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '3.0 [0.9-6.8]',
#    'NumericValue': 2.9565925,
#    'Low': 0.92140809,
#    'High': 6.7845456,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1990',
#    'TimeDimensionBegin': '1990-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1990-12-31T00:00:00+01:00'},
#   {'Id': 7582802,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'SYC',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2022,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '5.7 [4.7-6.9]',
#    'NumericValue': 5.7398744,
#    'Low': 4.6945255,
#    'High': 6.8807952,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2022',
#    'TimeDimensionBegin': '2022-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2022-12-31T00:00:00+01:00'},
#   {'Id': 7583803,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'SLE',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2003,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '6.7 [4.0-10.1]',
#    'NumericValue': 6.7036226,
#    'Low': 4.0088058,
#    'High': 10.13613,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2003',
#    'TimeDimensionBegin': '2003-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2003-12-31T00:00:00+01:00'},
#   {'Id': 7583804,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'WORLDBANKINCOMEGROUP',
#    'SpatialDim': 'WB_LMI',
#    'ParentLocationCode': None,
#    'TimeDimType': 'YEAR',
#    'ParentLocation': None,
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2001,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '21.5 [20.6-22.4]',
#    'NumericValue': 21.489231,
#    'Low': 20.554411,
#    'High': 22.417024,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2001',
#    'TimeDimensionBegin': '2001-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2001-12-31T00:00:00+01:00'},
#   {'Id': 7583815,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GUY',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 1999,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '8.8 [5.0-13.9]',
#    'NumericValue': 8.8156417,
#    'Low': 5.0197795,
#    'High': 13.853137,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1999',
#    'TimeDimensionBegin': '1999-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1999-12-31T00:00:00+01:00'},
#   {'Id': 7584085,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'KOR',
#    'ParentLocationCode': 'WPR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 1990,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '2.6 [1.6-4.0]',
#    'NumericValue': 2.5570264,
#    'Low': 1.5670614,
#    'High': 3.9537191,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1990',
#    'TimeDimensionBegin': '1990-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1990-12-31T00:00:00+01:00'},
#   {'Id': 7584241,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'TUV',
#    'ParentLocationCode': 'WPR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2013,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '0.7 [0.1-1.9]',
#    'NumericValue': 0.66443724,
#    'Low': 0.1272596,
#    'High': 1.8818142,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2013',
#    'TimeDimensionBegin': '2013-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2013-12-31T00:00:00+01:00'},
#   {'Id': 7584251,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FIN',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2011,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '1.2 [0.8-1.7]',
#    'NumericValue': 1.1773609,
#    'Low': 0.77547887,
#    'High': 1.6893584,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2011',
#    'TimeDimensionBegin': '2011-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2011-12-31T00:00:00+01:00'},
#   {'Id': 7584314,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'USA',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2003,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '1.5 [1.3-1.8]',
#    'NumericValue': 1.4958932,
#    'Low': 1.2581233,
#    'High': 1.7711306,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2003',
#    'TimeDimensionBegin': '2003-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2003-12-31T00:00:00+01:00'},
#   {'Id': 7584742,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GRL',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2008,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '0.9 [0.2-2.3]',
#    'NumericValue': 0.91645885,
#    'Low': 0.23480989,
#    'High': 2.3112029,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2008',
#    'TimeDimensionBegin': '2008-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2008-12-31T00:00:00+01:00'},
#   {'Id': 7584775,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GRC',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2012,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '1.3 [1.1-1.5]',
#    'NumericValue': 1.295761,
#    'Low': 1.1034079,
#    'High': 1.5074309,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2012',
#    'TimeDimensionBegin': '2012-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2012-12-31T00:00:00+01:00'},
#   {'Id': 7584796,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'SDN',
#    'ParentLocationCode': 'EMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2019,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '14.3 [9.4-20.0]',
#    'NumericValue': 14.326322,
#    'Low': 9.4470479,
#    'High': 20.01639,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2019',
#    'TimeDimensionBegin': '2019-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2019-12-31T00:00:00+01:00'},
#   {'Id': 7585218,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GNQ',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2014,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '6.3 [1.8-14.0]',
#    'NumericValue': 6.3110046,
#    'Low': 1.8240755,
#    'High': 13.967107,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2014',
#    'TimeDimensionBegin': '2014-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2014-12-31T00:00:00+01:00'},
#   {'Id': 7585628,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'MRT',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 1992,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '8.0 [2.5-17.5]',
#    'NumericValue': 8.0352679,
#    'Low': 2.4538785,
#    'High': 17.461717,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1992',
#    'TimeDimensionBegin': '1992-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1992-12-31T00:00:00+01:00'},
#   {'Id': 7585655,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GRL',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2015,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '1.2 [0.4-2.4]',
#    'NumericValue': 1.207603,
#    'Low': 0.44030119,
#    'High': 2.4112606,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2015',
#    'TimeDimensionBegin': '2015-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2015-12-31T00:00:00+01:00'},
#   {'Id': 7585880,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'PRK',
#    'ParentLocationCode': 'SEAR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'South-East Asia',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2017,
#    'Dim2Type': 'AGEGROUP',
# ...
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2012,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '1.7 [1.0-2.7]',
#    'NumericValue': 1.7163308,
#    'Low': 1.0134958,
#    'High': 2.7302314,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2012',
#    'TimeDimensionBegin': '2012-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2012-12-31T00:00:00+01:00'},
#   {'Id': 7730103,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BHS',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2013,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '3.4 [2.1-5.1]',
#    'NumericValue': 3.4245927,
#    'Low': 2.1152467,
#    'High': 5.1485375,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2013',
#    'TimeDimensionBegin': '2013-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2013-12-31T00:00:00+01:00'},
#   {'Id': 7730411,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'WORLDBANKINCOMEGROUP',
#    'SpatialDim': 'WB_LMI',
#    'ParentLocationCode': None,
#    'TimeDimType': 'YEAR',
#    'ParentLocation': None,
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2016,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '13.8 [12.9-14.6]',
#    'NumericValue': 13.758451,
#    'Low': 12.930048,
#    'High': 14.573918,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2016',
#    'TimeDimensionBegin': '2016-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2016-12-31T00:00:00+01:00'},
#   {'Id': 7730519,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'ROU',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2016,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '4.5 [3.6-5.5]',
#    'NumericValue': 4.5306031,
#    'Low': 3.6345828,
#    'High': 5.5265505,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2016',
#    'TimeDimensionBegin': '2016-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2016-12-31T00:00:00+01:00'},
#   {'Id': 7730695,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'COD',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2008,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '6.0 [3.7-9.4]',
#    'NumericValue': 6.0173705,
#    'Low': 3.6599644,
#    'High': 9.3810119,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2008',
#    'TimeDimensionBegin': '2008-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2008-12-31T00:00:00+01:00'},
#   {'Id': 7730938,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'DEU',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2006,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '1.5 [1.2-1.9]',
#    'NumericValue': 1.5110645,
#    'Low': 1.1693754,
#    'High': 1.9245559,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2006',
#    'TimeDimensionBegin': '2006-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2006-12-31T00:00:00+01:00'},
#   {'Id': 7731000,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AGO',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2010,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '8.7 [4.9-13.2]',
#    'NumericValue': 8.6599737,
#    'Low': 4.9195647,
#    'High': 13.208111,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2010',
#    'TimeDimensionBegin': '2010-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2010-12-31T00:00:00+01:00'},
#   {'Id': 7731082,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'BLZ',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2005,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '2.9 [1.4-5.0]',
#    'NumericValue': 2.8876821,
#    'Low': 1.400627,
#    'High': 5.0112542,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2005',
#    'TimeDimensionBegin': '2005-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2005-12-31T00:00:00+01:00'},
#   {'Id': 7731415,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'LBY',
#    'ParentLocationCode': 'EMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2002,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '5.3 [3.4-7.7]',
#    'NumericValue': 5.3184338,
#    'Low': 3.433961,
#    'High': 7.7147178,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2002',
#    'TimeDimensionBegin': '2002-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2002-12-31T00:00:00+01:00'},
#   {'Id': 7731429,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'GTM',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2020,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '2.1 [1.4-2.8]',
#    'NumericValue': 2.0653415,
#    'Low': 1.4400011,
#    'High': 2.8029071,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2020',
#    'TimeDimensionBegin': '2020-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2020-12-31T00:00:00+01:00'},
#   {'Id': 7731541,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'CAN',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 1990,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '1.4 [0.8-2.2]',
#    'NumericValue': 1.3995578,
#    'Low': 0.80190487,
#    'High': 2.2123538,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1990',
#    'TimeDimensionBegin': '1990-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1990-12-31T00:00:00+01:00'},
#   {'Id': 7731807,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'FSM',
#    'ParentLocationCode': 'WPR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Western Pacific',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2013,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '0.5 [0.1-1.6]',
#    'NumericValue': 0.54867812,
#    'Low': 0.09362796,
#    'High': 1.574675,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2013',
#    'TimeDimensionBegin': '2013-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2013-12-31T00:00:00+01:00'},
#   {'Id': 7731837,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'MRT',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 1997,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '13.5 [8.3-19.7]',
#    'NumericValue': 13.533857,
#    'Low': 8.2614094,
#    'High': 19.741435,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1997',
#    'TimeDimensionBegin': '1997-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1997-12-31T00:00:00+01:00'},
#   {'Id': 7732039,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'YEM',
#    'ParentLocationCode': 'EMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 1999,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '20.9 [16.4-25.6]',
#    'NumericValue': 20.867574,
#    'Low': 16.381466,
#    'High': 25.624239,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1999',
#    'TimeDimensionBegin': '1999-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1999-12-31T00:00:00+01:00'},
#   {'Id': 7732042,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'CAF',
#    'ParentLocationCode': 'AFR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Africa',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 2015,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '6.4 [1.8-14.8]',
#    'NumericValue': 6.4464189,
#    'Low': 1.7705342,
#    'High': 14.820211,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2015',
#    'TimeDimensionBegin': '2015-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2015-12-31T00:00:00+01:00'},
#   {'Id': 7732066,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'DMA',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_FMLE',
#    'TimeDim': 1998,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '3.0 [1.2-5.8]',
#    'NumericValue': 2.959088,
#    'Low': 1.1682215,
#    'High': 5.8197439,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1998',
#    'TimeDimensionBegin': '1998-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1998-12-31T00:00:00+01:00'},
#   {'Id': 7732361,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'YEM',
#    'ParentLocationCode': 'EMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Eastern Mediterranean',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2019,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '15.7 [10.8-20.9]',
#    'NumericValue': 15.668496,
#    'Low': 10.788248,
#    'High': 20.937279,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2019',
#    'TimeDimensionBegin': '2019-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2019-12-31T00:00:00+01:00'},
#   {'Id': 7732377,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'JAM',
#    'ParentLocationCode': 'AMR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Americas',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 2005,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS10-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '1.7 [1.0-2.5]',
#    'NumericValue': 1.6875707,
#    'Low': 1.0205542,
#    'High': 2.5344726,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2005',
#    'TimeDimensionBegin': '2005-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2005-12-31T00:00:00+01:00'},
#   {'Id': 7732595,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'AND',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 1997,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '2.1 [0.7-4.7]',
#    'NumericValue': 2.1209832,
#    'Low': 0.70170523,
#    'High': 4.7185104,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1997',
#    'TimeDimensionBegin': '1997-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1997-12-31T00:00:00+01:00'},
#   {'Id': 7732708,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'CZE',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 2004,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '3.0 [2.4-3.6]',
#    'NumericValue': 2.9766507,
#    'Low': 2.4083626,
#    'High': 3.6223643,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '2004',
#    'TimeDimensionBegin': '2004-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '2004-12-31T00:00:00+01:00'},
#   {'Id': 7732753,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'DNK',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_MLE',
#    'TimeDim': 1996,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-09',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '0.9 [0.6-1.2]',
#    'NumericValue': 0.88700773,
#    'Low': 0.61210748,
#    'High': 1.218964,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1996',
#    'TimeDimensionBegin': '1996-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1996-12-31T00:00:00+01:00'},
#   {'Id': 7732993,
#    'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'SpatialDimType': 'COUNTRY',
#    'SpatialDim': 'NLD',
#    'ParentLocationCode': 'EUR',
#    'TimeDimType': 'YEAR',
#    'ParentLocation': 'Europe',
#    'Dim1Type': 'SEX',
#    'Dim1': 'SEX_BTSX',
#    'TimeDim': 1990,
#    'Dim2Type': 'AGEGROUP',
#    'Dim2': 'AGEGROUP_YEARS05-19',
#    'Dim3Type': None,
#    'Dim3': None,
#    'DataSourceDimType': None,
#    'DataSourceDim': None,
#    'Value': '1.7 [1.0-2.6]',
#    'NumericValue': 1.6805926,
#    'Low': 0.97708609,
#    'High': 2.6346743,
#    'Comments': None,
#    'Date': '2024-02-29T16:06:41.017+01:00',
#    'TimeDimensionValue': '1990',
#    'TimeDimensionBegin': '1990-01-01T00:00:00+01:00',
#    'TimeDimensionEnd': '1990-12-31T00:00:00+01:00'},
#   ...]}

# %%
import pandas as pd

df = pd.DataFrame(data_obesity_adults['value'])
df.head()
# Out:
#         Id IndicatorCode SpatialDimType SpatialDim TimeDimType  \
# 0  7572989   NCD_BMI_30C        COUNTRY        PYF        YEAR
# 1  7573472   NCD_BMI_30C         REGION        WPR        YEAR
# 2  7573739   NCD_BMI_30C         REGION       SEAR        YEAR
# 3  7574136   NCD_BMI_30C        COUNTRY        FSM        YEAR
# 4  7575128   NCD_BMI_30C        COUNTRY        BGD        YEAR
#
#   ParentLocationCode   ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# 0                WPR  Western Pacific      SEX     1990  SEX_BTSX  ...
# 1               None             None      SEX     1991   SEX_MLE  ...
# 2               None             None      SEX     2003  SEX_FMLE  ...
# 3                WPR  Western Pacific      SEX     1997  SEX_FMLE  ...
# 4               SEAR  South-East Asia      SEX     2011   SEX_MLE  ...
#
#   DataSourceDim             Value NumericValue        Low       High Comments  \
# 0          None  33.2 [27.1-39.8]    33.224350  27.123517  39.766425     None
# 1          None     1.1 [1.0-1.2]     1.089884   1.000306   1.186920     None
# 2          None     3.5 [3.3-3.8]     3.511610   3.276324   3.765886     None
# 3          None  43.3 [37.7-49.1]    43.338764  37.729585  49.109054     None
# 4          None     1.3 [1.1-1.6]     1.321523   1.082014   1.585471     None
#
#                             Date  TimeDimensionValue  \
# 0  2024-02-29T16:06:41.017+01:00                1990
# 1  2024-05-23T13:35:20.483+02:00                1991
# 2  2024-05-23T13:35:20.483+02:00                2003
# 3  2024-02-29T16:06:41.017+01:00                1997
# 4  2024-02-29T16:06:41.017+01:00                2011
#
#           TimeDimensionBegin           TimeDimensionEnd
# 0  1990-01-01T00:00:00+01:00  1990-12-31T00:00:00+01:00
# 1  1991-01-01T00:00:00+01:00  1991-12-31T00:00:00+01:00
# 2  2003-01-01T00:00:00+01:00  2003-12-31T00:00:00+01:00
# 3  1997-01-01T00:00:00+01:00  1997-12-31T00:00:00+01:00
# 4  2011-01-01T00:00:00+01:00  2011-12-31T00:00:00+01:00
#
# [5 rows x 25 columns]

# %%
df_c = pd.DataFrame(data_obesity_children['value'])
df_c.head()
# Out:
#         Id   IndicatorCode SpatialDimType SpatialDim TimeDimType  \
# 0  7572487  NCD_BMI_PLUS2C        COUNTRY        KHM        YEAR
# 1  7573040  NCD_BMI_PLUS2C        COUNTRY        UKR        YEAR
# 2  7573345  NCD_BMI_PLUS2C        COUNTRY        EST        YEAR
# 3  7573498  NCD_BMI_PLUS2C        COUNTRY        NPL        YEAR
# 4  7573557  NCD_BMI_PLUS2C        COUNTRY        SLB        YEAR
#
#   ParentLocationCode   ParentLocation Dim1Type      Dim1  TimeDim  ...  \
# 0                WPR  Western Pacific      SEX   SEX_MLE     2017  ...
# 1                EUR           Europe      SEX   SEX_MLE     2006  ...
# 2                EUR           Europe      SEX  SEX_FMLE     1999  ...
# 3               SEAR  South-East Asia      SEX   SEX_MLE     1996  ...
# 4                WPR  Western Pacific      SEX  SEX_BTSX     2019  ...
#
#   DataSourceDim           Value NumericValue       Low       High Comments  \
# 0          None  9.8 [2.2-22.9]     9.778795  2.179117  22.852550     None
# 1          None   6.1 [3.6-9.4]     6.051800  3.577190   9.372717     None
# 2          None   2.4 [1.2-4.2]     2.412044  1.159774   4.192992     None
# 3          None   0.5 [0.1-1.6]     0.483587  0.070973   1.618876     None
# 4          None  7.0 [3.7-11.3]     7.035692  3.741321  11.325750     None
#
#                             Date  TimeDimensionValue  \
# 0  2024-02-29T16:06:41.017+01:00                2017
# 1  2024-02-29T16:06:41.017+01:00                2006
# 2  2024-02-29T16:06:41.017+01:00                1999
# 3  2024-02-29T16:06:41.017+01:00                1996
# 4  2024-02-29T16:06:41.017+01:00                2019
#
#           TimeDimensionBegin           TimeDimensionEnd
# 0  2017-01-01T00:00:00+01:00  2017-12-31T00:00:00+01:00
# 1  2006-01-01T00:00:00+01:00  2006-12-31T00:00:00+01:00
# 2  1999-01-01T00:00:00+01:00  1999-12-31T00:00:00+01:00
# 3  1996-01-01T00:00:00+01:00  1996-12-31T00:00:00+01:00
# 4  2019-01-01T00:00:00+01:00  2019-12-31T00:00:00+01:00
#
# [5 rows x 25 columns]

# %%
df_a = pd.DataFrame(data_underweight_adults['value'])
df_a.head()
# Out:
#         Id IndicatorCode SpatialDimType SpatialDim ParentLocationCode  \
# 0  7572619   NCD_BMI_18C        COUNTRY        SVK                EUR
# 1  7573535   NCD_BMI_18C        COUNTRY        LBN                EMR
# 2  7573931   NCD_BMI_18C        COUNTRY        TUR                EUR
# 3  7574144   NCD_BMI_18C        COUNTRY        EST                EUR
# 4  7576874   NCD_BMI_18C        COUNTRY        NLD                EUR
#
#   TimeDimType         ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# 0        YEAR                 Europe      SEX     2020  SEX_FMLE  ...
# 1        YEAR  Eastern Mediterranean      SEX     2021  SEX_BTSX  ...
# 2        YEAR                 Europe      SEX     2009  SEX_BTSX  ...
# 3        YEAR                 Europe      SEX     2017  SEX_BTSX  ...
# 4        YEAR                 Europe      SEX     1998  SEX_BTSX  ...
#
#   DataSourceDim          Value NumericValue       Low      High Comments  \
# 0          None  3.1 [1.7-5.0]     3.105481  1.735055  5.011791     None
# 1          None  2.4 [1.5-3.5]     2.373902  1.460991  3.507941     None
# 2          None  2.4 [2.1-2.7]     2.382590  2.095992  2.687877     None
# 3          None  1.6 [1.2-2.2]     1.639647  1.167246  2.213982     None
# 4          None  1.8 [1.4-2.2]     1.763170  1.382180  2.198168     None
#
#                             Date  TimeDimensionValue  \
# 0  2024-02-29T16:06:41.017+01:00                2020
# 1  2024-02-29T16:06:41.017+01:00                2021
# 2  2024-02-29T16:06:41.017+01:00                2009
# 3  2024-02-29T16:06:41.017+01:00                2017
# 4  2024-02-29T16:06:41.017+01:00                1998
#
#           TimeDimensionBegin           TimeDimensionEnd
# 0  2020-01-01T00:00:00+01:00  2020-12-31T00:00:00+01:00
# 1  2021-01-01T00:00:00+01:00  2021-12-31T00:00:00+01:00
# 2  2009-01-01T00:00:00+01:00  2009-12-31T00:00:00+01:00
# 3  2017-01-01T00:00:00+01:00  2017-12-31T00:00:00+01:00
# 4  1998-01-01T00:00:00+01:00  1998-12-31T00:00:00+01:00
#
# [5 rows x 25 columns]

# %%
df_b = pd.DataFrame(data_underweight_children['value'])
df_b.head()
# Out:
#         Id    IndicatorCode SpatialDimType SpatialDim ParentLocationCode  \
# 0  7573110  NCD_BMI_MINUS2C        COUNTRY        TUV                WPR
# 1  7573189  NCD_BMI_MINUS2C        COUNTRY        DNK                EUR
# 2  7573624  NCD_BMI_MINUS2C        COUNTRY        NGA                AFR
# 3  7573803  NCD_BMI_MINUS2C        COUNTRY        BRB                AMR
# 4  7574229  NCD_BMI_MINUS2C        COUNTRY        BFA                AFR
#
#   TimeDimType   ParentLocation Dim1Type      Dim1  TimeDim  ... DataSourceDim  \
# 0        YEAR  Western Pacific      SEX  SEX_FMLE     2005  ...          None
# 1        YEAR           Europe      SEX   SEX_MLE     2001  ...          None
# 2        YEAR           Africa      SEX   SEX_MLE     1999  ...          None
# 3        YEAR         Americas      SEX  SEX_FMLE     2002  ...          None
# 4        YEAR           Africa      SEX   SEX_MLE     2015  ...          None
#
#               Value NumericValue        Low       High Comments  \
# 0     0.8 [0.1-2.1]     0.752194   0.137415   2.145021     None
# 1     1.6 [1.2-2.0]     1.578330   1.179259   2.037699     None
# 2  21.5 [14.6-28.9]    21.477319  14.605850  28.872150     None
# 3    5.1 [1.5-11.8]     5.070809   1.464119  11.820976     None
# 4    8.5 [4.7-13.5]     8.490626   4.676703  13.481808     None
#
#                             Date  TimeDimensionValue  \
# 0  2024-02-29T16:06:41.017+01:00                2005
# 1  2024-02-29T16:06:41.017+01:00                2001
# 2  2024-02-29T16:06:41.017+01:00                1999
# 3  2024-02-29T16:06:41.017+01:00                2002
# 4  2024-02-29T16:06:41.017+01:00                2015
#
#           TimeDimensionBegin           TimeDimensionEnd
# 0  2005-01-01T00:00:00+01:00  2005-12-31T00:00:00+01:00
# 1  2001-01-01T00:00:00+01:00  2001-12-31T00:00:00+01:00
# 2  1999-01-01T00:00:00+01:00  1999-12-31T00:00:00+01:00
# 3  2002-01-01T00:00:00+01:00  2002-12-31T00:00:00+01:00
# 4  2015-01-01T00:00:00+01:00  2015-12-31T00:00:00+01:00
#
# [5 rows x 25 columns]

# %%
df['age_group'] = "adults"
df_a['age_group'] = "adults"
df_c['age_group'] = "children"
df_b['age_group'] = "children"

# %%
df.columns
# Out:
# Index(['Id', 'IndicatorCode', 'SpatialDimType', 'SpatialDim', 'TimeDimType',
#        'ParentLocationCode', 'ParentLocation', 'Dim1Type', 'TimeDim', 'Dim1',
#        'Dim2Type', 'Dim2', 'Dim3Type', 'Dim3', 'DataSourceDimType',
#        'DataSourceDim', 'Value', 'NumericValue', 'Low', 'High', 'Comments',
#        'Date', 'TimeDimensionValue', 'TimeDimensionBegin', 'TimeDimensionEnd',
#        'age_group'],
#       dtype='object')

# %%
df_a.columns
# Out:
# Index(['Id', 'IndicatorCode', 'SpatialDimType', 'SpatialDim',
#        'ParentLocationCode', 'TimeDimType', 'ParentLocation', 'Dim1Type',
#        'TimeDim', 'Dim1', 'Dim2Type', 'Dim2', 'Dim3Type', 'Dim3',
#        'DataSourceDimType', 'DataSourceDim', 'Value', 'NumericValue', 'Low',
#        'High', 'Comments', 'Date', 'TimeDimensionValue', 'TimeDimensionBegin',
#        'TimeDimensionEnd', 'age_group'],
#       dtype='object')

# %%
df_c.columns
# Out:
# Index(['Id', 'IndicatorCode', 'SpatialDimType', 'SpatialDim', 'TimeDimType',
#        'ParentLocationCode', 'ParentLocation', 'Dim1Type', 'Dim1', 'TimeDim',
#        'Dim2Type', 'Dim2', 'Dim3Type', 'Dim3', 'DataSourceDimType',
#        'DataSourceDim', 'Value', 'NumericValue', 'Low', 'High', 'Comments',
#        'Date', 'TimeDimensionValue', 'TimeDimensionBegin', 'TimeDimensionEnd',
#        'age_group'],
#       dtype='object')

# %%
df_b.columns
# Out:
# Index(['Id', 'IndicatorCode', 'SpatialDimType', 'SpatialDim',
#        'ParentLocationCode', 'TimeDimType', 'ParentLocation', 'Dim1Type',
#        'Dim1', 'TimeDim', 'Dim2Type', 'Dim2', 'Dim3Type', 'Dim3',
#        'DataSourceDimType', 'DataSourceDim', 'Value', 'NumericValue', 'Low',
#        'High', 'Comments', 'Date', 'TimeDimensionValue', 'TimeDimensionBegin',
#        'TimeDimensionEnd', 'age_group'],
#       dtype='object')

# %%
#df_obesity = pd.merge(df, df_c, how='outer')
df_obesity = pd.concat([df, df_c], ignore_index=True)
df_obesity.head()
# Out:
#         Id IndicatorCode SpatialDimType SpatialDim TimeDimType  \
# 0  7572989   NCD_BMI_30C        COUNTRY        PYF        YEAR
# 1  7573472   NCD_BMI_30C         REGION        WPR        YEAR
# 2  7573739   NCD_BMI_30C         REGION       SEAR        YEAR
# 3  7574136   NCD_BMI_30C        COUNTRY        FSM        YEAR
# 4  7575128   NCD_BMI_30C        COUNTRY        BGD        YEAR
#
#   ParentLocationCode   ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# 0                WPR  Western Pacific      SEX     1990  SEX_BTSX  ...
# 1               None             None      SEX     1991   SEX_MLE  ...
# 2               None             None      SEX     2003  SEX_FMLE  ...
# 3                WPR  Western Pacific      SEX     1997  SEX_FMLE  ...
# 4               SEAR  South-East Asia      SEX     2011   SEX_MLE  ...
#
#               Value NumericValue        Low       High Comments  \
# 0  33.2 [27.1-39.8]    33.224350  27.123517  39.766425     None
# 1     1.1 [1.0-1.2]     1.089884   1.000306   1.186920     None
# 2     3.5 [3.3-3.8]     3.511610   3.276324   3.765886     None
# 3  43.3 [37.7-49.1]    43.338764  37.729585  49.109054     None
# 4     1.3 [1.1-1.6]     1.321523   1.082014   1.585471     None
#
#                             Date TimeDimensionValue  \
# 0  2024-02-29T16:06:41.017+01:00               1990
# 1  2024-05-23T13:35:20.483+02:00               1991
# 2  2024-05-23T13:35:20.483+02:00               2003
# 3  2024-02-29T16:06:41.017+01:00               1997
# 4  2024-02-29T16:06:41.017+01:00               2011
#
#           TimeDimensionBegin           TimeDimensionEnd  age_group
# 0  1990-01-01T00:00:00+01:00  1990-12-31T00:00:00+01:00     adults
# 1  1991-01-01T00:00:00+01:00  1991-12-31T00:00:00+01:00     adults
# 2  2003-01-01T00:00:00+01:00  2003-12-31T00:00:00+01:00     adults
# 3  1997-01-01T00:00:00+01:00  1997-12-31T00:00:00+01:00     adults
# 4  2011-01-01T00:00:00+01:00  2011-12-31T00:00:00+01:00     adults
#
# [5 rows x 26 columns]

# %%
#df_malnutrition = pd.merge(df_a, df_b, how='outer')
df_malnutrition = pd.concat([df_a, df_b], ignore_index=True)
df_malnutrition.head()
# Out:
#         Id IndicatorCode SpatialDimType SpatialDim ParentLocationCode  \
# 0  7572619   NCD_BMI_18C        COUNTRY        SVK                EUR
# 1  7573535   NCD_BMI_18C        COUNTRY        LBN                EMR
# 2  7573931   NCD_BMI_18C        COUNTRY        TUR                EUR
# 3  7574144   NCD_BMI_18C        COUNTRY        EST                EUR
# 4  7576874   NCD_BMI_18C        COUNTRY        NLD                EUR
#
#   TimeDimType         ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# 0        YEAR                 Europe      SEX     2020  SEX_FMLE  ...
# 1        YEAR  Eastern Mediterranean      SEX     2021  SEX_BTSX  ...
# 2        YEAR                 Europe      SEX     2009  SEX_BTSX  ...
# 3        YEAR                 Europe      SEX     2017  SEX_BTSX  ...
# 4        YEAR                 Europe      SEX     1998  SEX_BTSX  ...
#
#            Value NumericValue       Low      High Comments  \
# 0  3.1 [1.7-5.0]     3.105481  1.735055  5.011791     None
# 1  2.4 [1.5-3.5]     2.373902  1.460991  3.507941     None
# 2  2.4 [2.1-2.7]     2.382590  2.095992  2.687877     None
# 3  1.6 [1.2-2.2]     1.639647  1.167246  2.213982     None
# 4  1.8 [1.4-2.2]     1.763170  1.382180  2.198168     None
#
#                             Date TimeDimensionValue  \
# 0  2024-02-29T16:06:41.017+01:00               2020
# 1  2024-02-29T16:06:41.017+01:00               2021
# 2  2024-02-29T16:06:41.017+01:00               2009
# 3  2024-02-29T16:06:41.017+01:00               2017
# 4  2024-02-29T16:06:41.017+01:00               1998
#
#           TimeDimensionBegin           TimeDimensionEnd  age_group
# 0  2020-01-01T00:00:00+01:00  2020-12-31T00:00:00+01:00     adults
# 1  2021-01-01T00:00:00+01:00  2021-12-31T00:00:00+01:00     adults
# 2  2009-01-01T00:00:00+01:00  2009-12-31T00:00:00+01:00     adults
# 3  2017-01-01T00:00:00+01:00  2017-12-31T00:00:00+01:00     adults
# 4  1998-01-01T00:00:00+01:00  1998-12-31T00:00:00+01:00     adults
#
# [5 rows x 26 columns]

# %%
filtered_data_obesity = df_obesity[(df_obesity['TimeDim'] >= 2012) & (df_obesity['TimeDim'] <= 2022)]
filtered_data_obesity.head()
# Out:
#          Id IndicatorCode SpatialDimType SpatialDim TimeDimType  \
# 5   7576087   NCD_BMI_30C        COUNTRY        SSD        YEAR
# 7   7576417   NCD_BMI_30C        COUNTRY        MDV        YEAR
# 8   7576865   NCD_BMI_30C        COUNTRY        LBN        YEAR
# 9   7577503   NCD_BMI_30C        COUNTRY        LKA        YEAR
# 10  7577719   NCD_BMI_30C        COUNTRY        FIN        YEAR
#
#    ParentLocationCode         ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# 5                 AFR                 Africa      SEX     2022  SEX_FMLE  ...
# 7                SEAR        South-East Asia      SEX     2018   SEX_MLE  ...
# 8                 EMR  Eastern Mediterranean      SEX     2012  SEX_FMLE  ...
# 9                SEAR        South-East Asia      SEX     2012  SEX_BTSX  ...
# 10                EUR                 Europe      SEX     2013  SEX_BTSX  ...
#
#                Value NumericValue        Low       High Comments  \
# 5    11.2 [6.4-17.6]    11.182951   6.424951  17.573600     None
# 7    10.3 [8.5-12.2]    10.303473   8.548930  12.238667     None
# 8   26.3 [23.7-29.0]    26.312965  23.693877  29.009429     None
# 9      5.8 [5.2-6.4]     5.798069   5.201678   6.423544     None
# 10  22.0 [20.9-23.1]    22.001809  20.904699  23.127373     None
#
#                              Date TimeDimensionValue  \
# 5   2024-02-29T16:06:41.017+01:00               2022
# 7   2024-02-29T16:06:41.017+01:00               2018
# 8   2024-02-29T16:06:41.017+01:00               2012
# 9   2024-02-29T16:06:41.017+01:00               2012
# 10  2024-02-29T16:06:41.017+01:00               2013
#
#            TimeDimensionBegin           TimeDimensionEnd  age_group
# 5   2022-01-01T00:00:00+01:00  2022-12-31T00:00:00+01:00     adults
# 7   2018-01-01T00:00:00+01:00  2018-12-31T00:00:00+01:00     adults
# 8   2012-01-01T00:00:00+01:00  2012-12-31T00:00:00+01:00     adults
# 9   2012-01-01T00:00:00+01:00  2012-12-31T00:00:00+01:00     adults
# 10  2013-01-01T00:00:00+01:00  2013-12-31T00:00:00+01:00     adults
#
# [5 rows x 26 columns]

# %%
filtered_data_malnutrition = df_malnutrition[(df_malnutrition['TimeDim'] >= 2012) & (df_malnutrition['TimeDim'] <= 2022)]
filtered_data_malnutrition.head()
# Out:
#         Id IndicatorCode SpatialDimType SpatialDim ParentLocationCode  \
# 0  7572619   NCD_BMI_18C        COUNTRY        SVK                EUR
# 1  7573535   NCD_BMI_18C        COUNTRY        LBN                EMR
# 3  7574144   NCD_BMI_18C        COUNTRY        EST                EUR
# 5  7576885   NCD_BMI_18C        COUNTRY        BTN               SEAR
# 9  7578787   NCD_BMI_18C        COUNTRY        PRI                AMR
#
#   TimeDimType         ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# 0        YEAR                 Europe      SEX     2020  SEX_FMLE  ...
# 1        YEAR  Eastern Mediterranean      SEX     2021  SEX_BTSX  ...
# 3        YEAR                 Europe      SEX     2017  SEX_BTSX  ...
# 5        YEAR        South-East Asia      SEX     2020   SEX_MLE  ...
# 9        YEAR               Americas      SEX     2012  SEX_FMLE  ...
#
#            Value NumericValue       Low      High Comments  \
# 0  3.1 [1.7-5.0]     3.105481  1.735055  5.011791     None
# 1  2.4 [1.5-3.5]     2.373902  1.460991  3.507941     None
# 3  1.6 [1.2-2.2]     1.639647  1.167246  2.213982     None
# 5  3.6 [2.2-5.4]     3.580639  2.160392  5.402577     None
# 9  3.0 [1.8-4.7]     3.040793  1.792959  4.695132     None
#
#                             Date TimeDimensionValue  \
# 0  2024-02-29T16:06:41.017+01:00               2020
# 1  2024-02-29T16:06:41.017+01:00               2021
# 3  2024-02-29T16:06:41.017+01:00               2017
# 5  2024-02-29T16:06:41.017+01:00               2020
# 9  2024-02-29T16:06:41.017+01:00               2012
#
#           TimeDimensionBegin           TimeDimensionEnd  age_group
# 0  2020-01-01T00:00:00+01:00  2020-12-31T00:00:00+01:00     adults
# 1  2021-01-01T00:00:00+01:00  2021-12-31T00:00:00+01:00     adults
# 3  2017-01-01T00:00:00+01:00  2017-12-31T00:00:00+01:00     adults
# 5  2020-01-01T00:00:00+01:00  2020-12-31T00:00:00+01:00     adults
# 9  2012-01-01T00:00:00+01:00  2012-12-31T00:00:00+01:00     adults
#
# [5 rows x 26 columns]

# %%
df_obesity = pd.DataFrame(filtered_data_obesity)

columns_to_keep = [
    "ParentLocation",
    "Dim1",
    "TimeDim",
    "Low",
    "High",
    "NumericValue",
    "SpatialDim",
    "age_group"
]

df_obesity = df_obesity[columns_to_keep]

df_obesity.head()
# Out:
#            ParentLocation      Dim1  TimeDim        Low       High  \
# 5                  Africa  SEX_FMLE     2022   6.424951  17.573600
# 7         South-East Asia   SEX_MLE     2018   8.548930  12.238667
# 8   Eastern Mediterranean  SEX_FMLE     2012  23.693877  29.009429
# 9         South-East Asia  SEX_BTSX     2012   5.201678   6.423544
# 10                 Europe  SEX_BTSX     2013  20.904699  23.127373
#
#     NumericValue SpatialDim age_group
# 5      11.182951        SSD    adults
# 7      10.303473        MDV    adults
# 8      26.312965        LBN    adults
# 9       5.798069        LKA    adults
# 10     22.001809        FIN    adults

# %%
df_malnutrition = pd.DataFrame(filtered_data_malnutrition)

columns_to_keep = [
    "ParentLocation",
    "Dim1",
    "TimeDim",
    "Low",
    "High",
    "NumericValue",
    "SpatialDim",
    "age_group"
]

df_malnutrition = df_malnutrition[columns_to_keep]

df_malnutrition.head()
# Out:
#           ParentLocation      Dim1  TimeDim       Low      High  NumericValue  \
# 0                 Europe  SEX_FMLE     2020  1.735055  5.011791      3.105481
# 1  Eastern Mediterranean  SEX_BTSX     2021  1.460991  3.507941      2.373902
# 3                 Europe  SEX_BTSX     2017  1.167246  2.213982      1.639647
# 5        South-East Asia   SEX_MLE     2020  2.160392  5.402577      3.580639
# 9               Americas  SEX_FMLE     2012  1.792959  4.695132      3.040793
#
#   SpatialDim age_group
# 0        SVK    adults
# 1        LBN    adults
# 3        EST    adults
# 5        BTN    adults
# 9        PRI    adults

# %%
# Rename columns
df_obesity = df_obesity.rename(
    columns={
        'TimeDim': 'Year',
        'Dim1': 'Gender',
        'NumericValue': 'Mean_Estimate',
        'Low': 'LowerBound',
        'High': 'UpperBound',
        'ParentLocation': 'Region',
        'SpatialDim': 'Country'
    }
)

# Standardize Gender values
df_obesity['Gender'] = (
    df_obesity['Gender']
    .astype(str)
    .str.strip()
    .str.lower()
    .replace({
        'sex_mle': 'Male',
        'sex_fmle': 'Female',
        'sex_btsx': 'Both',
    })
)

# Preview result
df_obesity.head()
# Out:
#                    Region  Gender  Year  LowerBound  UpperBound  \
# 5                  Africa  Female  2022    6.424951   17.573600
# 7         South-East Asia    Male  2018    8.548930   12.238667
# 8   Eastern Mediterranean  Female  2012   23.693877   29.009429
# 9         South-East Asia    Both  2012    5.201678    6.423544
# 10                 Europe    Both  2013   20.904699   23.127373
#
#     Mean_Estimate Country age_group
# 5       11.182951     SSD    adults
# 7       10.303473     MDV    adults
# 8       26.312965     LBN    adults
# 9        5.798069     LKA    adults
# 10      22.001809     FIN    adults

# %%
# Rename columns
df_malnutrition = df_malnutrition.rename(
    columns={
        'TimeDim': 'Year',
        'Dim1': 'Gender',
        'NumericValue': 'Mean_Estimate',
        'Low': 'LowerBound',
        'High': 'UpperBound',
        'ParentLocation': 'Region',
        'SpatialDim': 'Country'
    }
)

# Standardize Gender values
df_malnutrition['Gender'] = (
    df_malnutrition['Gender']
    .astype(str)
    .str.strip()
    .str.lower()
    .replace({
        'sex_mle': 'Male',
        'sex_fmle': 'Female',
        'sex_btsx': 'Both',
    })
)

# Preview result
df_malnutrition.head()
# Out:
#                   Region  Gender  Year  LowerBound  UpperBound  Mean_Estimate  \
# 0                 Europe  Female  2020    1.735055    5.011791       3.105481
# 1  Eastern Mediterranean    Both  2021    1.460991    3.507941       2.373902
# 3                 Europe    Both  2017    1.167246    2.213982       1.639647
# 5        South-East Asia    Male  2020    2.160392    5.402577       3.580639
# 9               Americas  Female  2012    1.792959    4.695132       3.040793
#
#   Country age_group
# 0     SVK    adults
# 1     LBN    adults
# 3     EST    adults
# 5     BTN    adults
# 9     PRI    adults

# %%
# !pip install pycountry
# Out:
# Collecting pycountry
#   Downloading pycountry-24.6.1-py3-none-any.whl.metadata (12 kB)
# Downloading pycountry-24.6.1-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 67.1 MB/s eta 0:00:00
# Installing collected packages: pycountry
# Successfully installed pycountry-24.6.1

# %%
import pycountry
import pandas as pd

# %%
special_cases = {
    'GLOBAL': 'Global',
    'WB_LMI': 'Low & Middle Income',
    'WB_HI': 'High Income',
    'WB_LI': 'Low Income',
    'WB_UMI': 'Upper Middle Income',
    'EMR': 'Eastern Mediterranean Region',
    'EUR': 'Europe',
    'AFR': 'Africa',
    'SEAR': 'South-East Asia Region',
    'WPR': 'Western Pacific Region',
    'AMR': 'Americas Region'
}

# %%
def convert_country_code(code):
    if pd.isna(code):
        return code

    # Handle special region / income codes
    if code in special_cases:
        return special_cases[code]

    try:
        country = pycountry.countries.get(alpha_3=code)
        return country.name if country else code
    except:
        return code

# %%
df_obesity['Country'] = df_obesity['Country'].apply(convert_country_code)
df_obesity.head()
# Out:
#                    Region  Gender  Year  LowerBound  UpperBound  \
# 5                  Africa  Female  2022    6.424951   17.573600
# 7         South-East Asia    Male  2018    8.548930   12.238667
# 8   Eastern Mediterranean  Female  2012   23.693877   29.009429
# 9         South-East Asia    Both  2012    5.201678    6.423544
# 10                 Europe    Both  2013   20.904699   23.127373
#
#     Mean_Estimate      Country age_group
# 5       11.182951  South Sudan    adults
# 7       10.303473     Maldives    adults
# 8       26.312965      Lebanon    adults
# 9        5.798069    Sri Lanka    adults
# 10      22.001809      Finland    adults

# %%
df_malnutrition['Country'] = df_malnutrition['Country'].apply(convert_country_code)
df_malnutrition.head()
# Out:
#                   Region  Gender  Year  LowerBound  UpperBound  Mean_Estimate  \
# 0                 Europe  Female  2020    1.735055    5.011791       3.105481
# 1  Eastern Mediterranean    Both  2021    1.460991    3.507941       2.373902
# 3                 Europe    Both  2017    1.167246    2.213982       1.639647
# 5        South-East Asia    Male  2020    2.160392    5.402577       3.580639
# 9               Americas  Female  2012    1.792959    4.695132       3.040793
#
#        Country age_group
# 0     Slovakia    adults
# 1      Lebanon    adults
# 3      Estonia    adults
# 5       Bhutan    adults
# 9  Puerto Rico    adults

# %%
df_obesity['CI_Width'] = df_obesity['UpperBound'] - df_obesity['LowerBound']
df_obesity.head()
# Out:
#                    Region  Gender  Year  LowerBound  UpperBound  \
# 5                  Africa  Female  2022    6.424951   17.573600
# 7         South-East Asia    Male  2018    8.548930   12.238667
# 8   Eastern Mediterranean  Female  2012   23.693877   29.009429
# 9         South-East Asia    Both  2012    5.201678    6.423544
# 10                 Europe    Both  2013   20.904699   23.127373
#
#     Mean_Estimate      Country age_group   CI_Width
# 5       11.182951  South Sudan    adults  11.148649
# 7       10.303473     Maldives    adults   3.689737
# 8       26.312965      Lebanon    adults   5.315552
# 9        5.798069    Sri Lanka    adults   1.221866
# 10      22.001809      Finland    adults   2.222674

# %%
df_malnutrition['CI_Width'] = df_malnutrition['UpperBound'] - df_malnutrition['LowerBound']
df_malnutrition.head()
# Out:
#                   Region  Gender  Year  LowerBound  UpperBound  Mean_Estimate  \
# 0                 Europe  Female  2020    1.735055    5.011791       3.105481
# 1  Eastern Mediterranean    Both  2021    1.460991    3.507941       2.373902
# 3                 Europe    Both  2017    1.167246    2.213982       1.639647
# 5        South-East Asia    Male  2020    2.160392    5.402577       3.580639
# 9               Americas  Female  2012    1.792959    4.695132       3.040793
#
#        Country age_group  CI_Width
# 0     Slovakia    adults  3.276735
# 1      Lebanon    adults  2.046950
# 3      Estonia    adults  1.046736
# 5       Bhutan    adults  3.242186
# 9  Puerto Rico    adults  2.902173

# %%
df_obesity['obesity_level'] = df_obesity['Mean_Estimate'].apply(
    lambda x: 'High' if x >= 30
    else 'Moderate' if 25 <= x <= 29.9
    else 'Low'
)
df_obesity.head()
# Out:
#                    Region  Gender  Year  LowerBound  UpperBound  \
# 5                  Africa  Female  2022    6.424951   17.573600
# 7         South-East Asia    Male  2018    8.548930   12.238667
# 8   Eastern Mediterranean  Female  2012   23.693877   29.009429
# 9         South-East Asia    Both  2012    5.201678    6.423544
# 10                 Europe    Both  2013   20.904699   23.127373
#
#     Mean_Estimate      Country age_group   CI_Width obesity_level
# 5       11.182951  South Sudan    adults  11.148649           Low
# 7       10.303473     Maldives    adults   3.689737           Low
# 8       26.312965      Lebanon    adults   5.315552      Moderate
# 9        5.798069    Sri Lanka    adults   1.221866           Low
# 10      22.001809      Finland    adults   2.222674           Low

# %%
df_malnutrition['malnutrition_level'] = df_malnutrition['Mean_Estimate'].apply(
    lambda x: 'High' if x >= 20
    else 'Moderate' if 10 <= x <= 19.9
    else 'Low'
)
df_malnutrition.head()
# Out:
#                   Region  Gender  Year  LowerBound  UpperBound  Mean_Estimate  \
# 0                 Europe  Female  2020    1.735055    5.011791       3.105481
# 1  Eastern Mediterranean    Both  2021    1.460991    3.507941       2.373902
# 3                 Europe    Both  2017    1.167246    2.213982       1.639647
# 5        South-East Asia    Male  2020    2.160392    5.402577       3.580639
# 9               Americas  Female  2012    1.792959    4.695132       3.040793
#
#        Country age_group  CI_Width malnutrition_level
# 0     Slovakia    adults  3.276735                Low
# 1      Lebanon    adults  2.046950                Low
# 3      Estonia    adults  1.046736                Low
# 5       Bhutan    adults  3.242186                Low
# 9  Puerto Rico    adults  2.902173                Low

# %%
df_malnutrition['age_group'] = (
    df_malnutrition['age_group']
    .astype(str)
    .str.strip()
    .str.lower()
    .replace({
        'adults': 'Adult',
        'children': 'Child/Adolescent'
    })
)

# %%
df_obesity['age_group'] = (
    df_obesity['age_group']
    .astype(str)
    .str.strip()
    .str.lower()
    .replace({
        'adults': 'Adult',
        'children': 'Child/Adolescent'
    })
)

# %%
df_obesity.head(20)
# Out:
#                    Region  Gender  Year  LowerBound  UpperBound  \
# 5                  Africa  Female  2022    6.424951   17.573600
# 7         South-East Asia    Male  2018    8.548930   12.238667
# 8   Eastern Mediterranean  Female  2012   23.693877   29.009429
# 9         South-East Asia    Both  2012    5.201678    6.423544
# 10                 Europe    Both  2013   20.904699   23.127373
# 11               Americas  Female  2021   25.165993   32.080960
# 14                 Africa    Both  2022    3.758678    8.385725
# 15               Americas  Female  2017   29.206374   36.806527
# 23        Western Pacific  Female  2017   62.485307   73.189330
# 28                 Africa  Female  2021    2.663616    4.798359
# 30               Americas    Male  2022   15.812518   23.845948
# 31  Eastern Mediterranean    Male  2013   15.831448   26.274461
# 32               Americas    Male  2017   15.640981   23.496141
# 36                 Europe    Male  2017   19.589353   25.070128
# 40        Western Pacific    Both  2014    3.892471    5.958806
# 46        Western Pacific    Both  2012    3.480289    3.965072
# 49        Western Pacific    Both  2015   14.947411   20.214677
# 50        Western Pacific    Both  2015    3.731304    4.302844
# 52               Americas    Male  2022   24.084263   38.968515
# 58        Western Pacific  Female  2016   71.297640   77.356488
#
#     Mean_Estimate                           Country age_group   CI_Width  \
# 5       11.182951                       South Sudan     Adult  11.148649
# 7       10.303473                          Maldives     Adult   3.689737
# 8       26.312965                           Lebanon     Adult   5.315552
# 9        5.798069                         Sri Lanka     Adult   1.221866
# 10      22.001809                           Finland     Adult   2.222674
# 11      28.638843                          Colombia     Adult   6.914967
# 14       5.713978                              Chad     Adult   4.627048
# 15      33.014712                       El Salvador     Adult   7.600153
# 23      68.016392                            Tuvalu     Adult  10.704023
# 28       3.650102                          Ethiopia     Adult   2.134744
# 30      19.673899                              Cuba     Adult   8.033430
# 31      20.790492              Syrian Arab Republic     Adult  10.443013
# 32      19.457661                       El Salvador     Adult   7.855160
# 36      22.335617                            Israel     Adult   5.480775
# 40       4.853307  Lao People's Democratic Republic     Adult   2.066335
# 46       3.715731                             Japan     Adult   0.484783
# 49      17.519403                           Vanuatu     Adult   5.267266
# 50       4.013698                             Japan     Adult   0.571539
# 52      31.246024                           Uruguay     Adult  14.884252
# 58      74.462157                             Tonga     Adult   6.058848
#
#    obesity_level
# 5            Low
# 7            Low
# 8       Moderate
# 9            Low
# 10           Low
# 11      Moderate
# 14           Low
# 15          High
# 23          High
# 28           Low
# 30           Low
# 31           Low
# 32           Low
# 36           Low
# 40           Low
# 46           Low
# 49           Low
# 50           Low
# 52          High
# 58          High

# %%
df_malnutrition.head(20)
# Out:
#                    Region  Gender  Year  LowerBound  UpperBound  \
# 0                  Europe  Female  2020    1.735055    5.011791
# 1   Eastern Mediterranean    Both  2021    1.460991    3.507941
# 3                  Europe    Both  2017    1.167246    2.213982
# 5         South-East Asia    Male  2020    2.160392    5.402577
# 9                Americas  Female  2012    1.792959    4.695132
# 13                 Europe    Both  2013    1.215451    3.475728
# 16               Americas  Female  2013    5.472148    9.136240
# 20               Americas    Both  2020    1.154099    2.037246
# 21               Americas  Female  2021    1.191577    6.639004
# 28                 Europe  Female  2020    1.126414    4.750001
# 35                 Europe    Both  2018    1.696525    3.292253
# 37                 Europe  Female  2021    1.221334    2.899139
# 41                   None    Both  2014    7.132421    8.080176
# 44                   None    Both  2016    2.675448    2.932974
# 46                 Africa    Both  2015   11.435567   16.753495
# 47                 Africa  Female  2012   14.116947   18.742332
# 49               Americas  Female  2021    0.657702   11.067051
# 51  Eastern Mediterranean  Female  2021    1.330391    3.560682
# 52                 Africa    Male  2012    4.299679    9.322575
# 57               Americas    Both  2021    3.027189    5.576880
#
#     Mean_Estimate                       Country age_group   CI_Width  \
# 0        3.105481                      Slovakia     Adult   3.276735
# 1        2.373902                       Lebanon     Adult   2.046950
# 3        1.639647                       Estonia     Adult   1.046736
# 5        3.580639                        Bhutan     Adult   3.242186
# 9        3.040793                   Puerto Rico     Adult   2.902173
# 13       2.189872                       Andorra     Adult   2.260277
# 16       7.200324                        Guyana     Adult   3.664092
# 20       1.555127                       Ecuador     Adult   0.883147
# 21       3.289035                       Grenada     Adult   5.447426
# 28       2.432318                    Montenegro     Adult   3.623587
# 35       2.415609                     Greenland     Adult   1.595728
# 37       1.958010                       Albania     Adult   1.677805
# 41       7.599712  Eastern Mediterranean Region     Adult   0.947755
# 44       2.803275                   High Income     Adult   0.257526
# 46      14.009073                      Botswana     Adult   5.317928
# 47      16.350642                       Senegal     Adult   4.625385
# 49       4.082650                       Bermuda     Adult  10.409349
# 51       2.279953          United Arab Emirates     Adult   2.230291
# 52       6.555401                    Cabo Verde     Adult   5.022896
# 57       4.164747                          Cuba     Adult   2.549691
#
#    malnutrition_level
# 0                 Low
# 1                 Low
# 3                 Low
# 5                 Low
# 9                 Low
# 13                Low
# 16                Low
# 20                Low
# 21                Low
# 28                Low
# 35                Low
# 37                Low
# 41                Low
# 44                Low
# 46           Moderate
# 47           Moderate
# 49                Low
# 51                Low
# 52                Low
# 57                Low

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
df_obesity.shape
# Out:
# (27720, 10)

# %%
df_malnutrition.shape
# Out:
# (27720, 10)

# %%
df_obesity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27720 entries, 5 to 83154
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Region         26268 non-null  object
#  1   Gender         27720 non-null  object
#  2   Year           27720 non-null  int64
#  3   LowerBound     27720 non-null  float64
#  4   UpperBound     27720 non-null  float64
#  5   Mean_Estimate  27720 non-null  float64
#  6   Country        27720 non-null  object
#  7   age_group      27720 non-null  object
#  8   CI_Width       27720 non-null  float64
#  9   obesity_level  27720 non-null  object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 2.3+ MB

# %%
df_malnutrition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27720 entries, 0 to 83159
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Region              26268 non-null  object
#  1   Gender              27720 non-null  object
#  2   Year                27720 non-null  int64
#  3   LowerBound          27720 non-null  float64
#  4   UpperBound          27720 non-null  float64
#  5   Mean_Estimate       27720 non-null  float64
#  6   Country             27720 non-null  object
#  7   age_group           27720 non-null  object
#  8   CI_Width            27720 non-null  float64
#  9   malnutrition_level  27720 non-null  object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 2.3+ MB

# %%
df_obesity.head()
# Out:
#                    Region  Gender  Year  LowerBound  UpperBound  \
# 5                  Africa  Female  2022    6.424951   17.573600
# 7         South-East Asia    Male  2018    8.548930   12.238667
# 8   Eastern Mediterranean  Female  2012   23.693877   29.009429
# 9         South-East Asia    Both  2012    5.201678    6.423544
# 10                 Europe    Both  2013   20.904699   23.127373
#
#     Mean_Estimate      Country age_group   CI_Width obesity_level
# 5       11.182951  South Sudan     Adult  11.148649           Low
# 7       10.303473     Maldives     Adult   3.689737           Low
# 8       26.312965      Lebanon     Adult   5.315552      Moderate
# 9        5.798069    Sri Lanka     Adult   1.221866           Low
# 10      22.001809      Finland     Adult   2.222674           Low

# %%
df_malnutrition.head()
# Out:
#                   Region  Gender  Year  LowerBound  UpperBound  Mean_Estimate  \
# 0                 Europe  Female  2020    1.735055    5.011791       3.105481
# 1  Eastern Mediterranean    Both  2021    1.460991    3.507941       2.373902
# 3                 Europe    Both  2017    1.167246    2.213982       1.639647
# 5        South-East Asia    Male  2020    2.160392    5.402577       3.580639
# 9               Americas  Female  2012    1.792959    4.695132       3.040793
#
#        Country age_group  CI_Width malnutrition_level
# 0     Slovakia     Adult  3.276735                Low
# 1      Lebanon     Adult  2.046950                Low
# 3      Estonia     Adult  1.046736                Low
# 5       Bhutan     Adult  3.242186                Low
# 9  Puerto Rico     Adult  2.902173                Low

# %%
df_obesity.isna().sum()
# Out:
# Region           1452
# Gender              0
# Year                0
# LowerBound          0
# UpperBound          0
# Mean_Estimate       0
# Country             0
# age_group           0
# CI_Width            0
# obesity_level       0
# dtype: int64

# %%
import plotly.express as px

# %%
df_obesity.shape
# Out:
# (27720, 10)

# %%
df_malnutrition.shape
# Out:
# (27720, 10)

# %%
df_obesity.isna().sum()
# Out:
# Region           1452
# Gender              0
# Year                0
# LowerBound          0
# UpperBound          0
# Mean_Estimate       0
# Country             0
# age_group           0
# CI_Width            0
# obesity_level       0
# dtype: int64

# %%
df_malnutrition.isna().sum()
# Out:
# Region                1452
# Gender                   0
# Year                     0
# LowerBound               0
# UpperBound               0
# Mean_Estimate            0
# Country                  0
# age_group                0
# CI_Width                 0
# malnutrition_level       0
# dtype: int64

# %%
df_obesity.describe()
# Out:
#                Year    LowerBound    UpperBound  Mean_Estimate      CI_Width
# count  27720.000000  27720.000000  27720.000000   27720.000000  27720.000000
# mean    2017.000000      9.393155     17.068488      12.761040      7.675334
# std        3.162335      9.893854     12.395013      10.858925      6.616899
# min     2012.000000      0.077541      0.547848       0.265672      0.216695
# 25%     2014.000000      2.354433      7.875503       4.753964      2.926708
# 50%     2017.000000      6.506534     13.704382       9.944541      5.480536
# 75%     2020.000000     12.697752     23.986050      17.482417     10.338880
# max     2022.000000     74.365371     87.868512      80.609250     40.554062

# %%
df_malnutrition.describe()
# Out:
#                Year    LowerBound    UpperBound  Mean_Estimate      CI_Width
# count  27720.000000  27720.000000  27720.000000   27720.000000  27720.000000
# mean    2017.000000      3.397094      8.147889       5.354451      4.750795
# std        3.162335      3.908061      6.443692       4.811220      4.257683
# min     2012.000000      0.023703      0.354833       0.175309      0.166679
# 25%     2014.000000      1.053666      3.143307       2.039278      1.603222
# 50%     2017.000000      1.907971      6.095557       3.597794      3.351093
# 75%     2020.000000      4.186440     11.526301       7.335245      6.530869
# max     2022.000000     31.365401     43.680286      35.894114     26.701744

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df_obesity["Mean_Estimate"], bins=30, kde=True)
plt.title("Distribution of Obesity Mean Estimates")
plt.xlabel("Obesity Percentage")
plt.show()

# %%
sns.histplot(df_malnutrition["Mean_Estimate"], bins=30, kde=True)
plt.title("Distribution of Malnutrition Mean Estimates")
plt.xlabel("Malnutrition Percentage")
plt.show()

# %%
sns.boxplot(data=df_obesity, x="Region", y="CI_Width")
plt.xticks(rotation=90)
plt.title("CI Width by Region – Obesity")
plt.show()

# %%
sns.boxplot(data=df_malnutrition, x="Region", y="CI_Width")
plt.xticks(rotation=90)
plt.title("CI Width by Region – Malnutrition")
plt.show()

# %%
global_obesity = df_obesity.groupby("Year")["Mean_Estimate"].mean().reset_index()

sns.lineplot(data=global_obesity, x="Year", y="Mean_Estimate", marker="o")
plt.title("Global Average Obesity Trend (2012–2022)")
plt.show()

# %%
global_mal = df_malnutrition.groupby("Year")["Mean_Estimate"].mean().reset_index()

sns.lineplot(data=global_mal, x="Year", y="Mean_Estimate", marker="o")
plt.title("Global Average Malnutrition Trend (2012–2022)")
plt.show()

# %%
india_ob = df_obesity[df_obesity["Country"]=="India"]

sns.lineplot(data=india_ob, x="Year", y="Mean_Estimate", hue="Gender")
plt.title("Obesity Trend in India by Gender")
plt.show()

# %%
region_ob = df_obesity.groupby("Region")["Mean_Estimate"].mean().sort_values(ascending=False)

region_ob.plot(kind="bar", figsize=(10,5))
plt.title("Average Obesity by Region")
plt.ylabel("Mean Obesity %")
plt.show()

# %%
region_mal = df_malnutrition.groupby("Region")["Mean_Estimate"].mean().sort_values(ascending=False)

region_mal.plot(kind="bar", figsize=(10,5), color="orange")
plt.title("Average Malnutrition by Region")
plt.ylabel("Mean Malnutrition %")
plt.show()

# %%
sns.boxplot(data=df_obesity, x="Gender", y="Mean_Estimate")
plt.title("Obesity Distribution by Gender")
plt.show()

# %%
sns.boxplot(data=df_malnutrition, x="Gender", y="Mean_Estimate")
plt.title("Malnutrition Distribution by Gender")
plt.show()

# %%
merged = (
    df_obesity.groupby("Country")["Mean_Estimate"].mean()
    .reset_index()
    .merge(
        df_malnutrition.groupby("Country")["Mean_Estimate"].mean().reset_index(),
        on="Country",
        suffixes=("_obesity","_malnutrition")
    )
)

sns.scatterplot(
    data=merged,
    x="Mean_Estimate_obesity",
    y="Mean_Estimate_malnutrition"
)
plt.xlabel("Avg Obesity %")
plt.ylabel("Avg Malnutrition %")
plt.title("Obesity vs Malnutrition by Country")
plt.show()

# %%
import sqlite3

# Create SQLite database (auto-created if not exists)
conn = sqlite3.connect("nutrition_paradox.db")

# Create cursor object
cursor = conn.cursor()

print("Database connected successfully")
# Out:
# Database connected successfully

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS obesity (
    Year INTEGER,
    Gender TEXT,
    Mean_Estimate REAL,
    LowerBound REAL,
    UpperBound REAL,
    Age_Group TEXT,
    Country TEXT,
    Region TEXT,
    CI_Width REAL,
    Obesity_Level TEXT
)
""")
cursor.execute("""
CREATE TABLE IF NOT EXISTS malnutrition (
    Year INTEGER,
    Gender TEXT,
    Mean_Estimate REAL,
    LowerBound REAL,
    UpperBound REAL,
    Age_Group TEXT,
    Country TEXT,
    Region TEXT,
    CI_Width REAL,
    Malnutrition_Level TEXT
)
""")

print("Tables created successfully")
# Out:
# Tables created successfully

# %%
print(df_obesity.columns)
print(df_malnutrition.columns)
# Out:
# Index(['Region', 'Gender', 'Year', 'LowerBound', 'UpperBound', 'Mean_Estimate',
#        'Country', 'age_group', 'CI_Width', 'obesity_level'],
#       dtype='object')
# Index(['Region', 'Gender', 'Year', 'LowerBound', 'UpperBound', 'Mean_Estimate',
#        'Country', 'age_group', 'CI_Width', 'malnutrition_level'],
#       dtype='object')

# %%
df_obesity.rename(columns={
    "age_group": "Age_Group",
    "obesity_level": "Obesity_Level"
}, inplace=True)

df_malnutrition.rename(columns={
    "age_group": "Age_Group",
    "malnutrition_level": "Malnutrition_Level"
}, inplace=True)

# %%
df_obesity = df_obesity[
    ["Year", "Gender", "Mean_Estimate", "LowerBound", "UpperBound",
     "Age_Group", "Country", "Region", "CI_Width", "Obesity_Level"]
]

df_malnutrition = df_malnutrition[
    ["Year", "Gender", "Mean_Estimate", "LowerBound", "UpperBound",
     "Age_Group", "Country", "Region", "CI_Width", "Malnutrition_Level"]
]

# %%
for _, row in df_obesity.iterrows():
    cursor.execute("""
        INSERT INTO obesity VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
    """, (
        int(row["Year"]),
        row["Gender"],
        float(row["Mean_Estimate"]),
        float(row["LowerBound"]),
        float(row["UpperBound"]),
        row["Age_Group"],
        row["Country"],
        row["Region"],
        float(row["CI_Width"]),
        row["Obesity_Level"]
    ))

# %%
for _, row in df_malnutrition.iterrows():
    cursor.execute("""
        INSERT INTO malnutrition VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
    """, (
        int(row["Year"]),
        row["Gender"],
        float(row["Mean_Estimate"]),
        float(row["LowerBound"]),
        float(row["UpperBound"]),
        row["Age_Group"],
        row["Country"],
        row["Region"],
        float(row["CI_Width"]),
        row["Malnutrition_Level"]
    ))

# %%
conn.commit()
conn.close()

print("Data inserted successfully and connection closed")
# Out:
# Data inserted successfully and connection closed

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("nutrition_paradox.db")

obesity_count = pd.read_sql(
    "SELECT COUNT(*) AS obesity_rows FROM obesity", conn
)
malnutrition_count = pd.read_sql(
    "SELECT COUNT(*) AS malnutrition_rows FROM malnutrition", conn
)

print(obesity_count)
print(malnutrition_count)

conn.close()
# Out:
#    obesity_rows
# 0         27720
#    malnutrition_rows
# 0              27720

# %%
import sqlite3
import pandas as pd

# Re-open connection
conn = sqlite3.connect("nutrition_paradox.db")

# Now run queries
print(pd.read_sql("SELECT * FROM obesity LIMIT 5", conn))
print(pd.read_sql("SELECT * FROM malnutrition LIMIT 5", conn))

# Close connection again
conn.close()
# Out:
#    Year  Gender  Mean_Estimate  LowerBound  UpperBound Age_Group      Country  \
# 0  2022  Female      11.182951    6.424951   17.573600     Adult  South Sudan
# 1  2018    Male      10.303473    8.548930   12.238667     Adult     Maldives
# 2  2012  Female      26.312965   23.693877   29.009429     Adult      Lebanon
# 3  2012    Both       5.798069    5.201678    6.423544     Adult    Sri Lanka
# 4  2013    Both      22.001809   20.904699   23.127373     Adult      Finland
#
#                   Region   CI_Width Obesity_Level
# 0                 Africa  11.148649           Low
# 1        South-East Asia   3.689737           Low
# 2  Eastern Mediterranean   5.315552      Moderate
# 3        South-East Asia   1.221866           Low
# 4                 Europe   2.222674           Low
#    Year  Gender  Mean_Estimate  LowerBound  UpperBound Age_Group      Country  \
# 0  2020  Female       3.105481    1.735055    5.011791     Adult     Slovakia
# 1  2021    Both       2.373902    1.460991    3.507941     Adult      Lebanon
# 2  2017    Both       1.639647    1.167246    2.213982     Adult      Estonia
# 3  2020    Male       3.580639    2.160392    5.402577     Adult       Bhutan
# 4  2012  Female       3.040793    1.792959    4.695132     Adult  Puerto Rico
#
#                   Region  CI_Width Malnutrition_Level
# 0                 Europe  3.276735                Low
# 1  Eastern Mediterranean  2.046950                Low
# 2                 Europe  1.046736                Low
# 3        South-East Asia  3.242186                Low
# 4               Americas  2.902173                Low

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT Region, AVG(Mean_Estimate) AS avg_obesity
FROM obesity
WHERE Year = 2022
GROUP BY Region
ORDER BY avg_obesity DESC
LIMIT 5;
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()
# Out:
#                   Region  avg_obesity
# 0        Western Pacific    22.639636
# 1               Americas    21.213601
# 2  Eastern Mediterranean    18.126910
# 3                 Europe    12.987338
# 4                   None    11.462648

# %%
conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT Country, AVG(Mean_Estimate) AS avg_obesity
FROM obesity
GROUP BY Country
ORDER BY avg_obesity DESC
LIMIT 5;
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()
# Out:
#           Country  avg_obesity
# 0            Niue    40.664873
# 1    Cook Islands    39.917173
# 2           Nauru    38.512101
# 3         Tokelau    37.960966
# 4  American Samoa    36.892015

# %%
conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT Year, AVG(Mean_Estimate) AS obesity_rate
FROM obesity
WHERE Country = 'India'
GROUP BY Year
ORDER BY Year;
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()
# Out:
#     Year  obesity_rate
# 0   2012      2.473178
# 1   2013      2.634653
# 2   2014      2.798749
# 3   2015      2.972813
# 4   2016      3.159576
# 5   2017      3.362175
# 6   2018      3.579292
# 7   2019      3.809013
# 8   2020      4.051149
# 9   2021      4.307816
# 10  2022      4.579179

# %%
conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT Gender, AVG(Mean_Estimate) AS avg_obesity
FROM obesity
GROUP BY Gender;
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()
# Out:
#    Gender  avg_obesity
# 0    Both    12.781969
# 1  Female    12.724456
# 2    Male    12.776696

# %%
conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT Age_Group, Obesity_Level, COUNT(DISTINCT Country) AS country_count
FROM obesity
GROUP BY Age_Group, Obesity_Level;
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()
# Out:
#           Age_Group Obesity_Level  country_count
# 0             Adult          High             94
# 1             Adult           Low            179
# 2             Adult      Moderate             99
# 3  Child/Adolescent          High             11
# 4  Child/Adolescent           Low            210
# 5  Child/Adolescent      Moderate             26

# %%
conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT Country, AVG(CI_Width) AS avg_ci
FROM obesity
GROUP BY Country
ORDER BY avg_ci DESC
LIMIT 5;
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()
# Out:
#                Country     avg_ci
# 0              Bermuda  24.593417
# 1       American Samoa  23.113530
# 2  Antigua and Barbuda  22.016214
# 3          Puerto Rico  21.698679
# 4              Grenada  21.458487

# %%
conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT Country, AVG(CI_Width) AS avg_ci
FROM obesity
GROUP BY Country
ORDER BY avg_ci ASC
LIMIT 5;
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()
# Out:
#                   Country    avg_ci
# 0                  Global  0.708953
# 1     Low & Middle Income  0.861060
# 2  South-East Asia Region  1.017775
# 3                   India  1.140133
# 4                   Japan  1.155903

# %%
conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT Age_Group, AVG(Mean_Estimate) AS avg_obesity
FROM obesity
GROUP BY Age_Group;
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()
# Out:
#           Age_Group  avg_obesity
# 0             Adult    21.833223
# 1  Child/Adolescent     9.736979

# %%
conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT Country,
       AVG(Mean_Estimate) AS avg_obesity,
       AVG(CI_Width) AS avg_ci
FROM obesity
GROUP BY Country
HAVING avg_obesity < 25 AND avg_ci < 2
ORDER BY avg_obesity
LIMIT 10;
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()
# Out:
#                   Country  avg_obesity    avg_ci
# 0             Timor-Leste     0.994067  1.273569
# 1                Ethiopia     1.491994  1.589414
# 2            Burkina Faso     1.721496  1.531514
# 3              Bangladesh     1.976673  1.663506
# 4                   India     3.429781  1.140133
# 5                   Japan     4.000332  1.155903
# 6  South-East Asia Region     4.236563  1.017775
# 7              Low Income     4.381297  1.870275
# 8                  Africa     4.672290  1.417837
# 9     Low & Middle Income     5.631030  0.861060

# %%
conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT f.Country, f.Year,
       (f.Mean_Estimate - m.Mean_Estimate) AS gender_gap
FROM obesity f
JOIN obesity m
ON f.Country = m.Country AND f.Year = m.Year
WHERE f.Gender = 'Female'
  AND m.Gender = 'Male'
  AND gender_gap > 5;
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()
# Out:
#                                Country  Year  gender_gap
# 0                          South Sudan  2022    7.040494
# 1                          South Sudan  2022    6.620367
# 2                          South Sudan  2022    5.549311
# 3                              Lebanon  2012    9.327608
# 4                              Lebanon  2012    8.999052
# ...                                ...   ...         ...
# 7373                           Bahamas  2021   15.275253
# 7374                           Bahamas  2021   12.640448
# 7375                           Bahamas  2021    6.107419
# 7376  Saint Vincent and the Grenadines  2020    6.715935
# 7377  Saint Vincent and the Grenadines  2020    5.159789
#
# [7378 rows x 3 columns]

# %%
conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT Year, AVG(Mean_Estimate) AS global_obesity
FROM obesity
GROUP BY Year
ORDER BY Year;
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()
# Out:
#     Year  global_obesity
# 0   2012       11.061969
# 1   2013       11.359637
# 2   2014       11.670343
# 3   2015       11.994231
# 4   2016       12.333907
# 5   2017       12.689997
# 6   2018       13.060296
# 7   2019       13.444604
# 8   2020       13.843002
# 9   2021       14.250923
# 10  2022       14.662533

# %%
conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT Age_Group, AVG(Mean_Estimate) AS avg_malnutrition
FROM malnutrition
GROUP BY Age_Group;
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()
# Out:
#           Age_Group  avg_malnutrition
# 0             Adult          5.940619
# 1  Child/Adolescent          5.159062

# %%
conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT Country, AVG(Mean_Estimate) AS avg_malnutrition
FROM malnutrition
GROUP BY Country
ORDER BY avg_malnutrition DESC
LIMIT 5;
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()
# Out:
#                   Country  avg_malnutrition
# 0                   India         22.142361
# 1  South-East Asia Region         19.238903
# 2              Bangladesh         18.245768
# 3               Sri Lanka         17.871907
# 4                 Eritrea         17.472508

# %%
conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT Year, AVG(Mean_Estimate) AS avg_malnutrition
FROM malnutrition
WHERE Region = 'Africa'
GROUP BY Year
ORDER BY Year;
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()
# Out:
#     Year  avg_malnutrition
# 0   2012          8.849655
# 1   2013          8.749857
# 2   2014          8.662762
# 3   2015          8.587719
# 4   2016          8.523125
# 5   2017          8.466465
# 6   2018          8.414722
# 7   2019          8.369700
# 8   2020          8.331320
# 9   2021          8.298626
# 10  2022          8.270096

# %%
conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT Gender, AVG(Mean_Estimate) AS avg_malnutrition
FROM malnutrition
GROUP BY Gender;
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()
# Out:
#    Gender  avg_malnutrition
# 0    Both          5.361553
# 1  Female          4.675483
# 2    Male          6.026317

# %%
conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT Age_Group, Malnutrition_Level, AVG(CI_Width) AS avg_ci
FROM malnutrition
GROUP BY Age_Group, Malnutrition_Level;
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()
# Out:
#           Age_Group Malnutrition_Level    avg_ci
# 0             Adult               High  9.253292
# 1             Adult                Low  2.639558
# 2             Adult           Moderate  7.639277
# 3  Child/Adolescent               High  7.876140
# 4  Child/Adolescent                Low  4.438274
# 5  Child/Adolescent           Moderate  9.903640

# %%
conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT Country, Year, AVG(Mean_Estimate) AS malnutrition_rate
FROM malnutrition
WHERE Country IN ('India','Nigeria','Brazil')
GROUP BY Country, Year
ORDER BY Country, Year;
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()
# Out:
#     Country  Year  malnutrition_rate
# 0    Brazil  2012           2.838653
# 1    Brazil  2013           2.781388
# 2    Brazil  2014           2.735034
# 3    Brazil  2015           2.698947
# 4    Brazil  2016           2.672241
# 5    Brazil  2017           2.653566
# 6    Brazil  2018           2.641574
# 7    Brazil  2019           2.634594
# 8    Brazil  2020           2.629412
# 9    Brazil  2021           2.626637
# 10   Brazil  2022           2.626854
# 11    India  2012          25.192435
# 12    India  2013          24.608118
# 13    India  2014          24.013357
# 14    India  2015          23.399620
# 15    India  2016          22.771373
# 16    India  2017          22.140419
# 17    India  2018          21.511674
# 18    India  2019          20.887197
# 19    India  2020          20.273682
# 20    India  2021          19.676078
# 21    India  2022          19.092013
# 22  Nigeria  2012          11.248457
# 23  Nigeria  2013          11.316421
# 24  Nigeria  2014          11.416175
# 25  Nigeria  2015          11.541387
# 26  Nigeria  2016          11.686106
# 27  Nigeria  2017          11.842102
# 28  Nigeria  2018          12.001994
# 29  Nigeria  2019          12.168214
# 30  Nigeria  2020          12.340927
# 31  Nigeria  2021          12.519245
# 32  Nigeria  2022          12.700027

# %%
conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT Region, AVG(Mean_Estimate) AS avg_malnutrition
FROM malnutrition
GROUP BY Region
ORDER BY avg_malnutrition ASC
LIMIT 5;
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()
# Out:
#                   Region  avg_malnutrition
# 0                 Europe          2.426759
# 1               Americas          3.174752
# 2        Western Pacific          3.434955
# 3  Eastern Mediterranean          6.661349
# 4                   None          8.354200

# %%
conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT Country,
       MAX(Mean_Estimate) - MIN(Mean_Estimate) AS change
FROM malnutrition
GROUP BY Country
HAVING change > 0;
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()
# Out:
#                     Country     change
# 0               Afghanistan  10.826293
# 1                    Africa   8.969943
# 2                   Albania   2.688058
# 3                   Algeria   3.535352
# 4            American Samoa   0.900433
# ..                      ...        ...
# 205                Viet Nam  13.660961
# 206  Western Pacific Region   4.945064
# 207                   Yemen   9.451436
# 208                  Zambia   9.316730
# 209                Zimbabwe  10.279486
#
# [210 rows x 2 columns]

# %%
conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT Year,
       MIN(Mean_Estimate) AS min_malnutrition,
       MAX(Mean_Estimate) AS max_malnutrition
FROM malnutrition
GROUP BY Year
ORDER BY Year;
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()
# Out:
#     Year  min_malnutrition  max_malnutrition
# 0   2012          0.175309         35.894114
# 1   2013          0.176421         35.694364
# 2   2014          0.177772         35.498199
# 3   2015          0.178445         35.312954
# 4   2016          0.178804         35.147691
# 5   2017          0.179286         34.997904
# 6   2018          0.179796         34.856236
# 7   2019          0.180428         34.715995
# 8   2020          0.181989         34.578446
# 9   2021          0.184717         34.429225
# 10  2022          0.188174         34.261948

# %%
conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT Country, Year, CI_Width
FROM malnutrition
WHERE CI_Width > 5
ORDER BY CI_Width DESC;
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()
# Out:
#            Country  Year   CI_Width
# 0          Senegal  2022  26.701744
# 1          Senegal  2021  25.679344
# 2          Senegal  2020  24.586366
# 3       Mauritania  2022  23.810544
# 4          Senegal  2019  23.466897
# ...            ...   ...        ...
# 9567        Jordan  2019   5.001890
# 9568       Comoros  2018   5.001566
# 9569   Philippines  2021   5.001525
# 9570  Sierra Leone  2021   5.000505
# 9571     Singapore  2014   5.000001
#
# [9572 rows x 3 columns]

# %%
conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT o.Country,
       AVG(o.Mean_Estimate) AS avg_obesity,
       AVG(m.Mean_Estimate) AS avg_malnutrition
FROM obesity o
JOIN malnutrition m
ON o.Country = m.Country
GROUP BY o.Country
LIMIT 5;
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()
# Out:
#           Country  avg_obesity  avg_malnutrition
# 0     Afghanistan     7.763365          9.263801
# 1          Africa     4.672290          9.739446
# 2         Albania    10.947071          1.996792
# 3         Algeria    15.051907          4.365333
# 4  American Samoa    36.892015          0.730369

# %%
conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT o.Gender,
       AVG(o.Mean_Estimate) AS avg_obesity,
       AVG(m.Mean_Estimate) AS avg_malnutrition
FROM obesity o
JOIN malnutrition m
ON o.Gender = m.Gender
GROUP BY o.Gender;
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()
# Out:
#    Gender  avg_obesity  avg_malnutrition
# 0    Both    12.781969          5.361553
# 1  Female    12.724456          4.675483
# 2    Male    12.776696          6.026317

# %%
conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT o.Region,
       AVG(o.Mean_Estimate) AS avg_obesity,
       AVG(m.Mean_Estimate) AS avg_malnutrition
FROM obesity o
JOIN malnutrition m
ON o.Region = m.Region
WHERE o.Region IN ('Africa','Americas')
GROUP BY o.Region;
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()

# %%
conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT o.Country
FROM obesity o
JOIN malnutrition m
ON o.Country = m.Country
GROUP BY o.Country
HAVING MAX(o.Mean_Estimate) > MIN(o.Mean_Estimate)
   AND MAX(m.Mean_Estimate) < MIN(m.Mean_Estimate);
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()

# %%
conn = sqlite3.connect("nutrition_paradox.db")

query = """
SELECT o.Age_Group, o.Year,
       AVG(o.Mean_Estimate) AS avg_obesity,
       AVG(m.Mean_Estimate) AS avg_malnutrition
FROM obesity o
JOIN malnutrition m
ON o.Year = m.Year AND o.Age_Group = m.Age_Group
GROUP BY o.Age_Group, o.Year
ORDER BY o.Age_Group, o.Year;
"""

df = pd.read_sql(query, conn)
print(df)

conn.close()

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("nutrition_paradox.db")

pd.read_sql("SELECT * FROM obesity", conn).to_csv("obesity.csv", index=False)
pd.read_sql("SELECT * FROM malnutrition", conn).to_csv("malnutrition.csv", index=False)

conn.close()
